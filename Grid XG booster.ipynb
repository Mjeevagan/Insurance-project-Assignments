# %%
#importing libraries
import pandas as pd
import numpy as np
import xgboost as xgb

# %%
dataset=pd.read_csv("insurance_project.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#in the dataset we have words so AI cant categroise so we using ONE HOT ENCODING to categrise words to number.
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#to pick the columns from the data we use below coding
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#to crate the model we have to segregate the datasets to independent and dependent to predict the values.
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
#split train and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
#standard scaler is provide the better results
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
#once we split and test the data we have to do Model Creation using Grid Adabooster
from sklearn.model_selection import GridSearchCV
xgb_model = xgb.XGBRegressor()
#beloww method we take all the parameter fited into the single model
param_grid = {'n_estimators': [50, 100, 200],'learning_rate': [0.01, 0.1, 1.0]}

#in the below method we fit all the models into the grid.
grid=GridSearchCV(xgb.XGBRegressor(),param_grid,refit=True,verbose=3,n_jobs=1)

#fitting the model for grid search
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=50;, score=0.143 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, n_estimators=50;, score=0.074 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, n_estimators=50;, score=0.043 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, n_estimators=50;, score=-0.011 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, n_estimators=50;, score=0.006 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.620 total time=   0.3s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.527 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.536 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.529 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.474 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.851 total time=   0.6s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.764 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.790 total time=   0.6s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.807 total time=   0.6s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.730 total time=   0.6s
# [CV 1/5] END learning_rate=0.1, n_estimators=50;, score=0.880 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, n_estimators=50;, score=0.831 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, n_estimators=50;, score=0.831 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, n_estimators=50;, score=0.769 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.869 total time=   0.3s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.753 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.826 total time=   0.3s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.815 total time=   0.3s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.750 total time=   0.3s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=0.852 total time=   0.6s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=0.719 total time=   0.6s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=0.812 total time=   0.6s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=0.795 total time=   0.6s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=0.736 total time=   0.6s
# [CV 1/5] END learning_rate=1.0, n_estimators=50;, score=0.742 total time=   0.1s
# [CV 2/5] END learning_rate=1.0, n_estimators=50;, score=0.588 total time=   0.1s
# [CV 3/5] END learning_rate=1.0, n_estimators=50;, score=0.752 total time=   0.4s
# [CV 4/5] END learning_rate=1.0, n_estimators=50;, score=0.751 total time=   0.1s
# [CV 5/5] END learning_rate=1.0, n_estimators=50;, score=0.719 total time=   0.1s
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=0.740 total time=   0.3s
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=0.584 total time=   0.2s
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=0.750 total time=   0.3s
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=0.718 total time=   0.3s
# [CV 1/5] END learning_rate=1.0, n_estimators=200;, score=0.740 total time=   0.6s
# [CV 2/5] END learning_rate=1.0, n_estimators=200;, score=0.584 total time=   0.6s
# [CV 3/5] END learning_rate=1.0, n_estimators=200;, score=0.750 total time=   0.6s
# [CV 4/5] END learning_rate=1.0, n_estimators=200;, score=0.750 total time=   0.6s
# [CV 5/5] END learning_rate=1.0, n_estimators=200;, score=0.718 total time=   0.6s
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=None, gpu_id=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None, ...),
#              n_jobs=1,
#              param_grid={'learning_rate': [0.01, 0.1, 1.0],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
#Print best parmeter after creating the model
re=grid.cv_results_
print("the R_score value for the best prameter{}:".format(grid.best_params_))
# Out:
# the R_score value for the best prameter{'learning_rate': 0.1, 'n_estimators': 50}:

# %%
#to create the table
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.178596      0.010433         0.014591    4.897653e-04
# 1       0.329998      0.004705         0.014990    8.714517e-07
# 2       0.665992      0.012901         0.015790    3.996852e-04
# 3       0.179490      0.000799         0.014591    4.896687e-04
# 4       0.337393      0.005197         0.014991    6.321084e-04
# 5       0.672387      0.015462         0.015790    1.325821e-03
# 6       0.243831      0.130894         0.014791    3.990186e-04
# 7       0.336194      0.003261         0.015191    3.999006e-04
# 8       0.662593      0.014386         0.015791    3.998534e-04
#
#   param_learning_rate param_n_estimators  \
# 0                0.01                 50
# 1                0.01                100
# 2                0.01                200
# 3                 0.1                 50
# 4                 0.1                100
# 5                 0.1                200
# 6                   1                 50
# 7                   1                100
# 8                   1                200
#
#                                          params  split0_test_score  \
# 0   {'learning_rate': 0.01, 'n_estimators': 50}           0.143013
# 1  {'learning_rate': 0.01, 'n_estimators': 100}           0.619780
# 2  {'learning_rate': 0.01, 'n_estimators': 200}           0.850684
# 3    {'learning_rate': 0.1, 'n_estimators': 50}           0.879525
# 4   {'learning_rate': 0.1, 'n_estimators': 100}           0.869319
# 5   {'learning_rate': 0.1, 'n_estimators': 200}           0.851826
# 6    {'learning_rate': 1.0, 'n_estimators': 50}           0.741523
# 7   {'learning_rate': 1.0, 'n_estimators': 100}           0.740005
# 8   {'learning_rate': 1.0, 'n_estimators': 200}           0.739969
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.074136           0.043392          -0.011021           0.006279
# 1           0.526641           0.536036           0.528546           0.473638
# 2           0.763585           0.789905           0.806670           0.729713
# 3           0.779218           0.831427           0.831092           0.769334
# 4           0.752960           0.826460           0.814719           0.750394
# 5           0.718988           0.811562           0.794973           0.736224
# 6           0.587773           0.751670           0.751145           0.718665
# 7           0.584231           0.750072           0.749921           0.718324
# 8           0.584040           0.750038           0.749870           0.718313
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.051160        0.054600                9
# 1         0.536928        0.047004                8
# 2         0.788112        0.040681                3
# 3         0.818119        0.040023                1
# 4         0.802770        0.045513                2
# 5         0.782715        0.048952                4
# 6         0.710155        0.062350                5
# 7         0.708511        0.063207                6
# 8         0.708446        0.063267                7

# %%
#Once model creted we have test the data 
age_input=float(input("AGE:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_input=int(input("Smoker yes 0 or 1:"))
# Out:
# AGE:25
# BMI:60
# Children:1
# Sex Male 0 or 1:1
# Smoker yes 0 or 1:1

# %%
#once we provide the value the model will predict the results
Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_input]])
print("Future_Prediction = {}".format(Future_Prediction))
# Out:
# Future_Prediction = [56531.73]
